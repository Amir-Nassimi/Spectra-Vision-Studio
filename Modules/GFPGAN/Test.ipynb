# %%
from PIL import Image
from GFPGAN.inference_gfpgan import GFPGAN
# Out:
# C:\Users\p.aghaomidi\XEye project\04 Debug\super_resolution\venv\lib\site-packages\torchvision\transforms\functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
img = Image.open('1.jpg')

my_class = GFPGAN()
output_img = my_class.super_res(img)
# Out:
# 	Tile 1/1
# 4.260729551315308

# %%
import matplotlib.pyplot as plt
plt.imshow(output_img)
