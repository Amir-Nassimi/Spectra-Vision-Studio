# %%
import matplotlib.pyplot as plt
from PIL import Image
from Multiple import MultipleSR

# %%
my_class = MultipleSR('C:/Users/p.aghaomidi/XEye project/04 Debug/super_resolution/Models/SRmodels/EDSR_x3.pb')
img = Image.open('1.jpg')
imgsr = my_class.super_resolution(img)

# %%
plt.imshow(imgsr)
